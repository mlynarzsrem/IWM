# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import math
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
import ipywidgets as widgets
# Load an color image in grayscale
img = cv2.imread('test.jpg',0)
plt.imshow(img)
plt.show()

# %%
from sympy import Eq, Symbol, solve
def getYValues(x0,y0,X,radius):
    y = Symbol('y')
    eqn = Eq((y**2 -2*y0*y +y0**2) + (X-x0)**2  -radius**2, 0.0)
    return solve(eqn)
def getXValues(x0,y0,a,b,radius):
    x = Symbol('x')
    eqn = Eq((a*x +b -y0)**2 +(x -x0)**2  , radius**2)
    return solve(eqn)
def getAB(X,Y,angle_rad,a=1):
    return a*math.tan(angle_rad),(Y- math.tan(angle_rad)*X*a)
def getRadians(angle):
    return (angle*math.pi)/180
def getBegining(x0,y0,radius,angle_rad):
    beginX = x0 + radius*math.sin(angle_rad)
    beginY= y0 +radius*math.cos(angle_rad)
    return beginX,beginY

# %%
def drawCircle(x0,y0,radius,ax):
    circle=plt.Circle((x0, y0),radius=radius,fill=False)
    ax.add_artist(circle)    

def drawLines(x0,y0,alpha,radius,n,l,ax):
    #Odległosc miedzy detektotami
    detectorDelta = float(l)/n
    beginX,beginY = getBegining(x0,y0,radius,getRadians(alpha))
    endX=2*x0 - beginX
    endY=2*y0 - beginY
    line = plt.Line2D([beginX,endX],[beginY,endY])
    ax.add_artist(line)
    for i in range(n):
        pass
    
def func(n,alpha,l):
    x0 =0.5; y0=0.5 ; radius =0.4
    plt.figure(figsize=(8,8))
    ax=plt.subplot(aspect='equal')
    drawCircle(x0,y0,radius,ax)
    drawLines(x0,y0,alpha,radius,n,l,ax)
    plt.show()
interact(func,n=(1,100),alpha =(0,360),l=(0,90));
# Out:
# interactive(children=(IntSlider(value=50, description='n', min=1), IntSlider(value=180, description='alpha', max=360), IntSlider(value=45, description='l', max=90), Output()), _dom_classes=('widget-interact',))

# %%
getXValues(4,4,1,2,2)
# Out:
# [2, 4]
